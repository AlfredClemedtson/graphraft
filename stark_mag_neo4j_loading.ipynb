# %%
import os
import torch

from stark_qa import load_skb
from stark_neo4j_loading import insert_nodes, insert_relationships, insert_node_embeddings

from neo4j import GraphDatabase
from dotenv import load_dotenv
from tqdm import tqdm

# %load_ext autoreload
# %autoreload 2

#load neo4j credentials
load_dotenv('../db.env', override=True)
NEO4J_URI = os.getenv('NEO4J_URI')
NEO4J_USERNAME = os.getenv('NEO4J_USERNAME')
NEO4J_PASSWORD = os.getenv('NEO4J_PASSWORD')
NEO4J_URI
# Out:
# 'bolt://localhost:7687'

# %%
dataset_name = 'mag'
skb = load_skb(dataset_name, download_processed=True, root=None)
# Out:
# Loading from /Users/sbr/.cache/huggingface/hub/datasets--snap-stanford--stark/snapshots/88269e23e90587f99476c5dd74e235a0877e69be/skb/mag/processed!

# %%
# Load pre-generated openai text-embedding-ada-002 embeddings
# Get emb_download.py from https://github.com/snap-stanford/stark. see Readme for other ways to generate embeddings
# !python emb_download.py --dataset mag --emb_dir .
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1HSfUrSKBa7mJbECFbnKPQgd6HSsI8spT
# From (redirected): https://drive.google.com/uc?id=1HSfUrSKBa7mJbECFbnKPQgd6HSsI8spT&confirm=t&uuid=6bd9e32b-7b2a-467d-99b6-f21171240769
# To: /Users/sbr/GraphRAFT/data_loading/mag/text-embedding-ada-002/query/query_emb_dict.pt
# 100%|██████████████████████████████████████| 85.6M/85.6M [00:04<00:00, 17.3MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1oVdScsDRuEpCFXtWQcTAx7ycvOggWF17
# From (redirected): https://drive.google.com/uc?id=1oVdScsDRuEpCFXtWQcTAx7ycvOggWF17&confirm=t&uuid=ec649d9d-fc49-490d-8e76-1573f32c421e
# To: /Users/sbr/GraphRAFT/data_loading/mag/text-embedding-ada-002/doc/candidate_emb_dict.pt
# 100%|██████████████████████████████████████| 4.51G/4.51G [03:22<00:00, 22.2MB/s]

# %%
skb.edge_type_dict
# Out:
# {0: 'author___affiliated_with___institution',
#  1: 'paper___cites___paper',
#  2: 'paper___has_topic___field_of_study',
#  3: 'author___writes___paper'}

# %%
dir(skb)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_build_sparse_adj',
#  '_process_raw',
#  'abstract_path',
#  'candidate_ids',
#  'candidate_types',
#  'edge_index',
#  'edge_type2id',
#  'edge_type_dict',
#  'edge_types',
#  'get_all_paths',
#  'get_candidate_ids',
#  'get_doc_info',
#  'get_edge_ids_by_type',
#  'get_edge_type_by_id',
#  'get_map',
#  'get_neighbor_nodes',
#  'get_node_ids_by_type',
#  'get_node_ids_by_value',
#  'get_node_type_by_id',
#  'get_rel_info',
#  'get_tuples',
#  'graph_data_root',
#  'is_rel_type',
#  'k_hop_neighbor',
#  'load_edge',
#  'load_english_paper_text',
#  'load_meta_data',
#  'mag_mapping_dir',
#  'mag_metadata_cache_dir',
#  'merged_filtered_path',
#  'node_attr_dict',
#  'node_info',
#  'node_type2id',
#  'node_type_dict',
#  'node_type_lst',
#  'node_types',
#  'num_candidates',
#  'num_edges',
#  'num_nodes',
#  'ogbn_mag_mapping_dir',
#  'paper100M_text_cache_dir',
#  'processed_data_dir',
#  'raw_data_dir',
#  'rel_type_lst',
#  'root',
#  'sample_paths',
#  'schema_dir',
#  'sparse_adj',
#  'sparse_adj_by_type',
#  'test_columns',
#  'text_root',
#  'title_path']

# %%
skb.node_attr_dict
# Out:
# {'paper': ['title', 'abstract', 'publication date', 'venue'],
#  'author': ['name'],
#  'institution': ['name'],
#  'field_of_study': ['name']}

# %%
emb_d = torch.load('./mag/text-embedding-ada-002/doc/candidate_emb_dict.pt', weights_only=False)

# %%
if dataset_name=='mag':
    #Rename attribute
    print("====== Preprocessing ======")
    for node_id, node in tqdm(skb.node_info.items()):
        if 'ConferenceSeriesId.1' in node.keys():
            node['ConferenceSeriesId1'] = node.pop('ConferenceSeriesId.1')
        
    with GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD)) as driver:
        insert_nodes(skb, driver=driver, key_property='new_id') 
        insert_relationships(skb=skb, driver=driver, dataset_name=dataset_name)
        
        abstract_embeddings = torch.load('./mag/text-embedding-ada-002/doc/candidate_emb_dict.pt', weights_only=False)
        insert_node_embeddings(embeddings=abstract_embeddings, embedding_name='text_embedding', driver=driver)
# Out:
# ====== Preprocessing ======
# 100%|██████████| 1872968/1872968 [00:00<00:00, 4481728.14it/s]
# ======  Loading Author nodes  ======
# 100%|██████████| 1104554/1104554 [00:35<00:00, 30692.24it/s]
# ======  Loading Institution nodes  ======
# 100%|██████████| 8701/8701 [00:00<00:00, 22925.48it/s]
# ======  Loading FieldOfStudy nodes  ======
# 100%|██████████| 59469/59469 [00:01<00:00, 30146.38it/s]
# ======  Loading Paper nodes  ======
# 100%|██████████| 700244/700244 [01:25<00:00, 8229.95it/s]
# ======  Loading AFFILIATED_WITH edges  ======
# 100%|██████████| 2058324/2058324 [00:33<00:00, 61063.67it/s]
# ======  Loading CITES edges  ======
# 100%|██████████| 9719488/9719488 [03:08<00:00, 51483.72it/s]
# ======  Loading HAS_TOPIC edges  ======
# 100%|██████████| 14486538/14486538 [04:01<00:00, 60109.80it/s]
# ======  Loading WRITES edges  ======
# 100%|██████████| 13537766/13537766 [04:21<00:00, 51684.33it/s]
# ======  Loading embeddings (text_embedding) ======
# 100%|██████████| 700244/700244 [31:54<00:00, 365.67it/s]

# %%
import torch

emb = torch.load('../data-loading/emb/amazon/text-embedding-ada-002/doc/candidate_emb_dict.pt')

from tqdm import tqdm

# format embedding records
emb_records = []
for k,v in tqdm(emb.items()):
  emb_records.append({"nodeId":k ,"textEmbedding": v.squeeze().tolist()})
emb_records[:10]
# Out:
# 100%|██████████| 957192/957192 [01:33<00:00, 10266.44it/s]
# [{'nodeId': 0,
#   'textEmbedding': [-0.017573531717061996,
#    -0.014251705259084702,
#    -0.020346183329820633,
#    -0.026507634669542313,
#    0.009302452206611633,
#    0.0024176998995244503,
#    -0.0062686069868505,
#    -0.024699382483959198,
#    -0.013983815908432007,
#    -0.04058521240949631,
#    0.01153262984007597,
#    0.0057897549122571945,
#    0.01642160676419735,
#    -0.013414551503956318,
#    -0.008230895735323429,
#    0.010836117900907993,
#    0.016180507838726044,
#    0.0014692047843709588,
#    -0.026735341176390648,
#    -0.0220204908400774,
#    -0.020198844373226166,
#    0.015242895111441612,
#    -0.03929934278130531,
#    0.008426833897829056,
#    -0.01301609631627798,
#    -0.018871361389756203,
#    0.02202318236231804,
#    -0.009719212539494038,
#    0.007859770208597183,
#    0.016893230378627777,
#    -0.0005394525942392647,
#    -0.011881968006491661,
#    -0.011809436604380608,
#    0.017697671428322792,
#    0.00894774217158556,
#    -0.0305950790643692,
#    -0.008789491839706898,
#    0.01623385399580002,
#    -0.002111653797328472,
#    0.021706681698560715,
#    -0.0010385182686150074,
#    -0.02597944252192974,
#    -0.020836304873228073,
#    -0.004717840347439051,
#    -0.019939551129937172,
#    0.017394358292222023,
#    -0.020941805094480515,
#    0.012956752441823483,
#    -0.026124505326151848,
#    -0.016378916800022125,
#    -0.011644592508673668,
#    -0.011644592508673668,
#    -0.01819879747927189,
#    0.034788716584444046,
#    -0.012574314139783382,
#    -0.015943728387355804,
#    0.022234182804822922,
#    0.220284566283226,
#    0.0039002131670713425,
#    -0.007305894047021866,
#    0.03863947466015816,
#    0.012514970265328884,
#    0.02824769727885723,
#    0.021113242954015732,
#    -0.010569809004664421,
#    -0.000303519336739555,
#    -0.018568048253655434,
#    0.0013352378737181425,
#    0.0038375724107027054,
#    -0.014941476285457611,
#    -0.0041079167276620865,
#    -0.0014399138744920492,
#    -0.024581564590334892,
#    -0.04420461505651474,
#    -0.016220666468143463,
#    -0.01244243886321783,
#    -0.03191383183002472,
#    0.01720973290503025,
#    -0.004520027432590723,
#    -0.01293697115033865,
#    -0.00542337354272604,
#    0.02291993424296379,
#    -0.004335402045398951,
#    -0.006353094708174467,
#    0.015376664698123932,
#    0.012890814803540707,
#    0.016207478940486908,
#    -0.005083794239908457,
#    -0.021073680371046066,
#    -0.0003527665394358337,
#    -0.007497113198041916,
#    -0.008796085603535175,
#    0.00954777467995882,
#    0.011051153764128685,
#    -0.020889054983854294,
#    0.020532989874482155,
#    0.0039035100489854813,
#    -0.006897080224007368,
#    0.025966254994273186,
#    -0.013939223252236843,
#    -0.02054617740213871,
#    -0.01633935421705246,
#    0.004796965513378382,
#    ...]}]

# %%
from langchain_openai import OpenAIEmbeddings
embedding_model = OpenAIEmbeddings(model="text-embedding-ada-002")

import itertools

def chunked(it, size):
    it = iter(it)
    while True:
        chunk = tuple(itertools.islice(it, size))
        if not chunk:
            return
        yield chunk

# %%
from tqdm import tqdm
import pandas as pd

# create node_df
author_list = []
institution_list = []
field_of_study_list = []

authors = skb.get_node_ids_by_type('author')
for i in authors:
    author_list.append(skb[i].dictionary)

institutions = skb.get_node_ids_by_type('institution')
for i in institutions:
    institution_list.append(skb[i].dictionary)

fields_of_study = skb.get_node_ids_by_type('field_of_study')
for i in fields_of_study:
    field_of_study_list.append(skb[i].dictionary)


author_df = pd.DataFrame(author_list)
institution_df = pd.DataFrame(institution_list)
field_of_study_df = pd.DataFrame(field_of_study_list)

# %%
author_df
# Out:
#               id      mag_id   Rank           DisplayName  \
# 0              0       29650  16355  Alexander Wagenpfahl
# 1              1       39382  18658         Torben Jabben
# 2              2       41399  13895     Igor A. Abrikosov
# 3              3       46586  15055          Lars Goerigk
# 4              4       60751  16821       Yu. V. Kaletina
# ...          ...         ...    ...                   ...
# 1104549  1134644  3012560199     -1                    -1
# 1104550  1134645  3012560861     -1                    -1
# 1104551  1134646  3012560907     -1                    -1
# 1104552  1134647  3012561154     -1                    -1
# 1104553  1134648  3012561163     -1                    -1
#
#          LastKnownAffiliationId  PaperCount  CitationCount    type   new_id
# 0                      25974101          16            982  author        0
# 1                      31512782           8             21  author        1
# 2                     102134673         409           7624  author        2
# 3                     165779595          47           6816  author        3
# 4                    1313323035          45            105  author        4
# ...                         ...         ...            ...     ...      ...
# 1104549                      -1          -1             -1  author  1104549
# 1104550                      -1          -1             -1  author  1104550
# 1104551                      -1          -1             -1  author  1104551
# 1104552                      -1          -1             -1  author  1104552
# 1104553                      -1          -1             -1  author  1104553
#
# [1104554 rows x 9 columns]

# %%
author_names = author_df['DisplayName'].tolist()
author_names = [str(x) for x in author_names]
author_nodeids = author_df['id'].tolist()
author_names_dict = {i: name for i, name in zip(author_nodeids, author_names)}
author_names_dict
# Out:
# {0: 'Alexander Wagenpfahl',
#  1: 'Torben Jabben',
#  2: 'Igor A. Abrikosov',
#  3: 'Lars Goerigk',
#  4: 'Yu. V. Kaletina',
#  5: 'Torsten Mayer-Gürr',
#  6: 'Bao Shang-lian',
#  7: 'Vedran Lekic',
#  8: 'Nurettin Yamankaradeniz',
#  9: 'Jutharatana Klinkaewnarong',
#  10: 'Geva Arwas',
#  11: 'Riet Labie',
#  12: 'Sedat Alkoy',
#  13: 'Bruce R. Gerratt',
#  14: 'Fernando Fernández-Lázaro',
#  15: 'Peter A. Gnoffo',
#  16: 'David Trdlička',
#  17: 'Francesc Rocadenbosch',
#  18: 'Marta Mas-Torrent',
#  19: 'Babak Nadjar Araabi',
#  20: 'Thierry Giamarchi',
#  21: 'David Rodriguez-Larrea',
#  22: 'Thomas Quella',
#  23: 'Mikael C. Rechtsman',
#  24: 'Victor Vartanian',
#  25: 'Naomi J. Halas',
#  26: 'Guillem Pérez-Nadal',
#  27: 'Jonathan Bergknoff',
#  28: 'Consuelo Cid Tortuero',
#  29: 'Severin N. Habisreutinger',
#  30: 'Vikas Sudesh',
#  32: 'Dmitriy A. Dikin',
#  33: 'Shi Yuejiang',
#  34: 'Eric Le Moal',
#  35: 'Ugo Piomelli',
#  36: 'Dominic de Lanauze',
#  37: 'Arun M. Thalapillil',
#  38: 'Gao Yuan-Ning',
#  39: 'Hamed Alipour-Banaei',
#  40: 'Leo P. Kadanoff',
#  41: 'Ghislaine Ngo Boum',
#  42: 'Joseph D. Touch',
#  43: 'Denis Parenthoine',
#  44: 'Arash Ahmadivand',
#  45: 'Xie Yuan-Xiang',
#  46: 'Kyryl Zagorovsky',
#  47: 'Jiang Benxue',
#  48: 'Kirill S. Napolskii',
#  49: 'Athikom Roeksabutr',
#  50: 'Giorgio Besagni',
#  51: 'Oliver Fuhrer',
#  52: 'Kerry J. Vahala',
#  53: 'Giovanni Vleminckx',
#  54: 'Tyler K. Perrachione',
#  55: 'Mahesh Pandikunta',
#  56: 'Hsu Hou-Tse',
#  58: 'Susan Stepney',
#  59: 'Russell Glavey',
#  60: 'Leila Mokhtari Oranj',
#  61: 'Ferry Kienberger',
#  62: 'David Goluskin',
#  63: 'Jan Bernkopf',
#  64: 'Chen Shengbo',
#  65: 'Priyamvada Jadaun',
#  66: 'Xu Zi-Jian',
#  67: 'Sebastian Trujillo-Gomez',
#  68: 'Emad Samadiani',
#  69: 'Ian Garrick-Bethell',
#  70: 'Francesco Intravaia',
#  71: 'Mark R. Rosiek',
#  72: 'Julia Yael Plavnik',
#  73: 'Daniel Forchheimer',
#  74: 'Shan Chongxin',
#  75: 'Olimpia Budriga',
#  76: 'Jay A. LaVerne',
#  77: 'Stephen Whitelam',
#  78: 'Veronica Vespini',
#  79: 'Slawomir Kadlubowski',
#  80: 'Eric Neuscamman',
#  81: 'Gao Shouting',
#  82: 'Sebastien Peirani',
#  83: 'Luai M. Al-Hadhrami',
#  84: 'Oleksandr V. Popovych',
#  85: 'I. Valais',
#  86: 'Thierry Livache',
#  87: 'Vladimir V. Tsukruk',
#  88: 'Daniel J. Gargas',
#  89: 'Philippe Bekaert',
#  90: 'Athanasios Tsanas',
#  91: 'M. Volwerk',
#  92: 'Panu Pekko',
#  93: 'Max Wintermark',
#  94: 'Sandro Scandolo',
#  95: 'Huang Kai-Yun',
#  96: 'Estela Blaisten-Barojas',
#  97: 'Oznur Usanmaz',
#  98: 'Christian Karlewski',
#  99: 'Costas Smaragdakis',
#  100: 'Han Peide',
#  101: 'E. I. Kamitsos',
#  102: 'Amir H. Gandjbakhche',
#  103: 'Moritz McGarrie',
#  104: 'David B. Saakian',
#  105: 'Qian Shengbang',
#  106: 'Velia Minicozzi',
#  107: 'Cédric Larricq',
#  108: 'Nicolas Bruot',
#  109: 'Marcella Di Criscienzo',
#  110: 'Dominik Janzing',
#  111: 'Peter J. Marcer',
#  112: 'Tahirih Motazedian',
#  113: 'Ignazio Scimemi',
#  114: 'Péter Jeszenszki',
#  115: 'Thomas Leitgeb',
#  116: 'Basar Bolukbas',
#  117: 'Sergei M. Bachilo',
#  118: 'Wang Bingzhong',
#  119: 'Francesco Panza',
#  120: 'Evan Mitsoulis',
#  121: 'Adam Kantanista',
#  122: 'Olivier Desjardins',
#  123: 'J. Krustok',
#  124: 'Michal Pudlak',
#  125: 'Peter Vandenabeele',
#  126: 'M. Savinov',
#  127: 'Carlo Iazeolla',
#  128: 'Nicola Di Lieto',
#  129: 'Eric Vauthey',
#  130: 'A. Espargilière',
#  131: 'Gary L. Gallia',
#  132: 'Iraj Mortazavi',
#  133: 'Leon Poladian',
#  134: 'David Smithe',
#  135: 'Wang Mingzhe',
#  136: 'Prasert Kenpankho',
#  137: 'Cristina Puzzarini',
#  138: 'Andreas Feymark',
#  139: 'Sushil K. Satija',
#  140: 'Carmine Ortix',
#  141: 'Laurens D. A. Siebbeles',
#  142: 'Frederick L. Dryer',
#  143: 'Fabien Cheynis',
#  144: 'Kevin M. Hickson',
#  145: 'Michael Helgert',
#  146: 'Willy Supatto',
#  147: 'Salvador Barrera-Figueroa',
#  148: 'Bruce A. Garetz',
#  149: 'Özgür E. Müstecaplıoğlu',
#  150: 'Eli Kraisler',
#  151: 'Tom Wenseleers',
#  152: 'Rainer Künnemeyer',
#  153: 'Tuncay Döğeroğlu',
#  154: 'Fumio Shohda',
#  155: 'Zhang Caili',
#  156: 'Sarawuth Labuayai',
#  157: 'Barry D. Dunietz',
#  158: 'Dario Tamascelli',
#  159: 'Arun Kannawadi',
#  160: 'Javier Rodríguez-Laguna',
#  161: 'Tomoya Takiwaki',
#  162: 'Henrik Lycksam',
#  163: 'Kaori Ihida-Stansbury',
#  164: 'Iris Pilch',
#  165: 'Craig R. Birtcher',
#  166: 'Bennett Ponting',
#  168: 'Yang Zhen-Biao',
#  169: 'Mike Woerdemann',
#  170: 'Frank Katzenberg',
#  171: 'Adam Dioguardi',
#  172: 'Nestor C. Tsirliganis',
#  173: 'Zbigniew R. Struzik',
#  174: 'T. Maggipinto',
#  175: 'Rym Bouchendira',
#  176: 'Florian Weigend',
#  177: 'Giorgio Mantica',
#  178: 'Tomasz Szymborski',
#  179: 'Ester Quintana-Rizzo',
#  180: 'Chen Liangfu',
#  181: 'Toni Björninen',
#  182: 'Afshin Montakhab',
#  183: 'Florian A. Potra',
#  184: 'Huang Wan-Xia',
#  185: 'He Duanwei',
#  186: 'Karim Louertani',
#  187: 'Milan M. Cirkovic',
#  188: 'Alexander Kuhlicke',
#  189: 'Harry L. Swinney',
#  190: 'Oleg Chalykh',
#  191: 'Wu Shao-Quan',
#  192: 'Zanda Gavare',
#  193: 'Rachael M. Roettenbacher',
#  194: 'Moayad Husein Flaifel',
#  195: 'Leonid I. Manevitch',
#  196: 'Philip Lah',
#  197: 'Yuki Obukuro',
#  198: 'Anton V. Bourdine',
#  199: 'Konstantin G. Zloshchastiev',
#  200: 'Jacob Kongsted',
#  201: 'Ingo Scholtes',
#  202: 'John E. Gizis',
#  203: 'Monica Colpi',
#  204: 'László Pálfalvi',
#  205: 'Mario Roncadin',
#  206: 'Philippe Paillou',
#  207: 'Cristian Ilioaia',
#  208: 'Tamas Heffter',
#  209: 'Pierre Borgnat',
#  210: 'Ronald J. Ferek',
#  211: 'E. Taralli',
#  212: 'Yusuke Daiko',
#  213: 'Kenji Wakimizu',
#  214: 'Watson P. Varricatt',
#  215: 'Rodney S. Ruoff',
#  216: 'Ufuk Olgac',
#  217: 'Ali Bentouaf',
#  218: 'Martin Lopez de Bertodano',
#  219: 'Tang Zhi-Lie',
#  220: 'Harshad Surdi',
#  221: 'O. Cazarez-Candia',
#  222: 'El Hassan Ridouane',
#  223: 'Jorge Páramos',
#  224: 'Sergio Desogus',
#  225: 'Meni Wanunu',
#  226: 'Rachel Crespo-Otero',
#  227: 'Gao Zi-You',
#  228: 'Piotr Ryczkowski',
#  229: 'Yu. A. Baimova',
#  230: 'Yoshiaki Sofue',
#  231: 'Frerik van Beijnum',
#  232: 'Anthony D. Dutoi',
#  233: 'Günther Rupprechter',
#  234: 'Yoshiki Numamoto',
#  235: 'Jacques Zylberg',
#  236: 'Nikitas I. Gidopoulos',
#  237: 'Mohamed A. Abd Al-Halim',
#  238: 'Domenico Acchiappati',
#  239: 'Trey Quiller',
#  240: 'Anzheng GuoLu',
#  241: 'Tomas Tolenis',
#  242: 'Ouyang Chu-Ying',
#  243: 'Slava V. Rotkin',
#  244: 'W. Olchawa',
#  245: 'Behrooz Abiri',
#  246: 'Michelle A. Caler',
#  247: 'Pedro Almendral',
#  248: 'Andrew A. Lacis',
#  249: 'Fernando Peruani',
#  250: 'Mohamed El Mankibi',
#  251: 'Sinisa Coh',
#  252: 'Miloud Chahlafi',
#  253: 'Benoit Noetinger',
#  254: 'Maciej Szkulmowski',
#  255: 'Karel Van Acoleyen',
#  256: 'Ali Akbar Ashkarran',
#  257: 'Balázs Bánhelyi',
#  258: 'Tang Guo-Ning',
#  259: 'Piotr Kaczmarkiewicz',
#  260: 'Ivar Farup',
#  261: 'Peter Unsbo',
#  262: 'Damien Hutsemekers',
#  263: 'Marisol De Brabandere',
#  264: 'Sandra Pluczyk',
#  265: 'Tang Chao-jing',
#  266: 'Gilles Hunault',
#  267: 'Lida Ebrahimi Zohravi',
#  268: 'David R. Ciardi',
#  269: 'Peter Tiňo',
#  270: 'Jukka Aumanen',
#  271: 'Eric A. Galapon',
#  272: 'Buncha Munmuangsaen',
#  273: 'Ivan Ohlídal',
#  274: 'Ingmar H. Riedel-Kruse',
#  275: 'Irene Tamborra',
#  276: 'Akihiko Teshigahara',
#  277: 'Ignacio Llatser',
#  278: 'Tanner DeLawyer',
#  279: 'Caner Nazaroglu',
#  280: 'Manousos Valyrakis',
#  281: 'Evaggelos Kritsikis',
#  282: 'Nouamane Laanait',
#  283: 'Ghouti Medjahdi',
#  284: 'Grant Matsushige',
#  285: 'Yu. L. Lomukhin',
#  286: 'Christopher J. Progler',
#  287: 'Joel E. Tohline',
#  288: 'Shiki Yagai',
#  289: 'Karl S. Booksh',
#  290: 'Andrei Zagrai',
#  291: 'Igor O. Slieptsov',
#  292: 'Solomon Manukure',
#  293: 'Matti Kaisti',
#  294: 'Parinya Pongsoi',
#  295: 'Jan Unkelbach',
#  296: 'Igor E. Agranovski',
#  297: 'Daniel Andreica',
#  298: 'Michael C. Sukop',
#  299: 'Hassan Hajabdollahi',
#  300: 'Timothy J. Nokes-Malach',
#  301: 'Michiaki Myotoku',
#  302: 'James P. Kossin',
#  303: 'Manlio Tassieri',
#  304: 'Dino Pedreschi',
#  305: 'Pavel Kwiecien',
#  306: 'Yevgeny Beiderman',
#  307: 'Christopher J. Paciorek',
#  308: 'Dominique Delande',
#  309: 'Kantesh Balani',
#  310: 'Arnaud Le Febvrier',
#  311: 'Andreas Janshoff',
#  312: 'Watchara Liewrian',
#  313: 'Somporn Chantara',
#  314: 'Devendraa Siingh',
#  315: 'Rafael Piestun',
#  316: 'Josef Lindman Hörnlund',
#  317: 'Andreas Tratnig',
#  318: 'Grey Sh. Boltachev',
#  319: 'Huang Si-Xun',
#  320: 'Manuel Dossot',
#  321: 'Mounir Bouzaiane',
#  322: 'E. Daddi',
#  323: 'Simon Grosse-Kreul',
#  324: 'Maik Dobbermann',
#  325: 'Nathan A. Mahynski',
#  326: 'Fumitaka Shichinomiya',
#  327: 'Eric A. Grulke',
#  328: 'P. Geltenbort',
#  329: 'Mahdi Azarpeyvand',
#  330: 'Cosmin Crucean',
#  331: 'Makoto Wakeshima',
#  332: 'Roger T. Bonnecaze',
#  333: 'Jozef Genzor',
#  334: 'Bernard Hallet',
#  335: 'Omar Bentata',
#  336: 'Ewa Bulska',
#  337: 'Olalla A. Castro-Alvaredo',
#  338: 'Didier Sornette',
#  339: 'Kazuo Takimiya',
#  340: 'David H. Tofsted',
#  341: 'Carlos A. Jiménez-Hoyos',
#  342: 'Dwight G. Rickel',
#  343: 'Geneviève Mialon',
#  344: 'Christian Nansen',
#  346: 'Davide Gadia',
#  347: 'Billy Kaldvee',
#  348: 'Kurt Liffman',
#  349: 'Ishwaree P. Neupane',
#  350: 'Naveen Bijalwan',
#  351: 'Tamas I. Gombosi',
#  352: 'Liu Litian',
#  353: 'Bastien Denarie',
#  354: 'Shigeo Urushidani',
#  355: 'Zhao Beijun',
#  356: 'Alison M. Funston',
#  357: 'Ivano Bilotti',
#  358: 'Jia Quan-Jie',
#  359: 'Pedro Marronetti',
#  360: 'Claudine Vanbauce',
#  361: 'Mauro Gemmi',
#  362: 'Dai Tongyu',
#  363: 'Tos T. J. M. Berendschot',
#  364: 'Nobuyuki Sawado',
#  365: 'Pasquale Di Nezza',
#  366: 'Xue Junshuai',
#  367: 'Joshua R. Codoni',
#  368: 'Michio Sadatomi',
#  369: 'Kevin J. Disotell',
#  370: 'Markus Aspelmeyer',
#  371: 'Benjamin Constantineau',
#  372: 'Ratindranath Akhoury',
#  373: 'Lisa Edelhäuser',
#  374: 'Shuki Wolfus',
#  375: 'Fabio Governato',
#  376: 'Olli Taanila',
#  377: 'Jun Fujikami',
#  378: 'Jens E. Bækhøj',
#  379: 'Emmanuel Yomba',
#  380: 'Erion Gjonaj',
#  381: 'Hidehito Nanto',
#  382: 'Christophe Deroulers',
#  383: 'Wang Peng-Ye',
#  384: 'Dimitris Kugiumtzis',
#  385: 'Mila Kryjevskaia',
#  386: 'Aurora Pribram-Jones',
#  387: 'Aya Kamaya',
#  388: 'Hajime Tomokage',
#  389: 'Delia Ionescu-Kruse',
#  390: 'Eial Teomy',
#  391: 'Andreas Flache',
#  392: 'Lorenzo Maccone',
#  393: 'Ilaria Ciofini',
#  394: 'Gelsor Norsang',
#  395: 'Catherine A. Pilachowski',
#  396: 'Akinobu Doté',
#  397: 'Markus A. Luty',
#  398: 'Emma S. G. Rainey',
#  399: 'Daniel T. Bowron',
#  400: 'Paul A. Menchhofer',
#  401: 'Raja Giryes',
#  402: 'Sebastian Schrewe',
#  403: 'R. Skartlien',
#  404: 'Yu. G. Ukraintsev',
#  405: 'Stella M. Marinakos',
#  406: 'Zhang Linwen',
#  407: 'Bernd von Issendorff',
#  408: 'Uri Hadar',
#  409: 'Katrien Van Slambrouck',
#  410: 'Fedwa El-Mellouhi',
#  411: 'R. Rekola',
#  412: 'Linas Vilčiauskas',
#  413: 'E. Jerby',
#  414: 'Christine M. Hrenya',
#  415: 'Ajaya K. Sigdel',
#  416: 'Rafal Klajn',
#  417: 'Agapios Sachinidis',
#  418: 'Ron O. Dror',
#  419: 'Roberto Emparan',
#  420: 'Yoel Feler',
#  421: 'Amir Yusefli',
#  422: 'Tobat P. I. Saragi',
#  424: 'Thomas M. Gurrieri',
#  425: 'Supaporn Wansom',
#  426: 'Konrad Piszczatowski',
#  427: 'Siamak Mehrnami',
#  428: 'Lyes Kadem',
#  429: 'Lobat Tayebi',
#  430: 'Daniel Szeremley',
#  431: 'Zenji Yatabe',
#  432: 'Fredi Tröltzsch',
#  433: 'Gary P. Kushto',
#  434: 'Gerrit Ansmann',
#  435: 'Eric M. Taleff',
#  436: 'Zoran Arsov',
#  437: 'Thomas Boch',
#  438: 'Muhammed Yonac',
#  439: 'Noriko Tomuro',
#  440: 'Gene F. Mazenko',
#  441: 'Raymond A. DeCarlo',
#  442: 'Osamu Kamiya',
#  443: 'Niu Yu-Quan',
#  444: 'Michael W. Reeks',
#  445: 'James S. Stolken',
#  446: 'Eshwar Thouti',
#  447: 'Rima Budvytyte',
#  448: 'Sabine von Hünerbein',
#  449: 'Ulrike Romatschke',
#  450: 'Matthew J. Olszta',
#  451: 'Hubert J. Krenner',
#  452: 'Vina Faramarzi',
#  453: 'David Greynat',
#  454: 'Damien Violeau',
#  455: 'Oleksii Matsedonskyi',
#  456: 'Sven Nebelung',
#  457: 'Hugues Duflo',
#  458: 'Luca Baiotti',
#  459: 'Shi Mian-Gong',
#  460: 'Jean Daillant',
#  462: 'Oleh Hul',
#  463: 'Justin L. Smoyer',
#  464: 'Navadol Laosiripojana',
#  465: 'Victoria Birkedal',
#  466: 'Rainer Steinwandt',
#  467: 'Thierry Darmanin',
#  468: 'Hartawan Laksmono',
#  469: 'Morteza Fathipour',
#  471: 'Wolfgang Rindler',
#  472: 'Anna Karion',
#  473: 'Prakash Karipoth',
#  474: 'Thomas Lunner',
#  475: 'Alice Bows',
#  476: 'Erik Waltersson',
#  477: 'Miroslava Unkašević',
#  478: 'Dieter M. Herlach',
#  479: 'Ali Imaanpur',
#  480: 'Fernando Mellibovsky',
#  481: 'Jacek Miękisz',
#  482: 'Sridhar Thyageswaran',
#  483: 'Sergei A. Decterov',
#  484: 'Uwe Ruschewitz',
#  485: 'Francisco Trivinho-Strixino',
#  486: 'Livio Pizzocchero',
#  487: 'Xavier Mateos',
#  488: 'Janina Maultzsch',
#  489: 'Chen Hongjian',
#  490: 'Yu. A. Plastinin',
#  491: 'Nicholas S. Dufault',
#  492: 'Fumihide Iwamuro',
#  493: 'Ramón Tena-Zaera',
#  494: 'Shoichi Kutsumizu',
#  495: 'Peter Lodahl',
#  496: 'Leslie M. Hartten',
#  497: 'Jan Regtmeier',
#  498: 'Norman Gürlebeck',
#  499: 'Erik Gerwick',
#  500: 'Hans Van Winckel',
#  501: 'Osamu Tamura',
#  502: 'Worachest Pirompugd',
#  503: 'Ahmad Rami El-Nabulsi',
#  504: 'Redouane Ghoubali',
#  505: 'Fabien Goulay',
#  506: 'J. Niemczura',
#  507: 'Ning Xi-Jing',
#  508: 'Alberto Diez-Tejedor',
#  509: 'Bartolomeo Civalleri',
#  510: 'Liu Zeng-rong',
#  511: 'Giorgos Kallis',
#  512: 'Charles A. DiMarzio',
#  513: 'Christine Chory',
#  514: 'Hiroshi Moritake',
#  515: 'Gary W. Carhart',
#  516: 'Kim A. Winick',
#  517: 'Oren Suchoi',
#  518: 'Olivier Bernus',
#  519: 'Stephen F Kry',
#  520: 'Constantinos S. Pattichis',
#  521: 'Karin Knesaurek',
#  522: 'Michael Reggelin',
#  523: 'Titus Vlase',
#  524: 'Elias C. Aifantis',
#  525: 'Beatrice Cobucci-Ponzano',
#  526: 'Tarun K. Chandrayadula',
#  527: 'Khaled M. Chahrour',
#  528: 'Yousif Kelaita',
#  529: 'Akira Heya',
#  530: 'Nils von den Driesch',
#  531: 'Marios Raspopoulos',
#  532: 'Peter Broekmann',
#  533: 'Ralph Seulin',
#  534: 'Nikodem Szpak',
#  535: 'George G. Malliaras',
#  536: 'Angel Sanz-Andrés',
#  537: 'Ali Beskok',
#  538: 'Kenneth W. Jucks',
#  539: 'Qi Yue-Rong',
#  540: 'Yonathan Schwarzkopf',
#  541: 'Askar Hamdulla',
#  542: 'Niklas Wellander',
#  543: 'Ingomar Kelbassa',
#  544: 'G. Wachutka',
#  545: 'Atsushi Ishizumi',
#  546: 'Daniel C. Fabrycky',
#  547: 'Olivier Thériault',
#  548: 'Jiang Zhi-jin',
#  549: 'Volker Gaibler',
#  550: 'Alex Boussioutas',
#  551: 'Colette Morche',
#  552: 'Alberto González-Castrillo',
#  553: 'Zhang Zong-Zhi',
#  554: 'H. Bulou',
#  555: 'Savely G. Karshenboim',
#  556: 'Lucel Sirghi',
#  557: 'Christian Hainzl',
#  558: 'Saeid Moslehpour',
#  559: 'Chinaruk Thianpong',
#  560: 'Jan Awrejcewicz',
#  561: 'Swann Piatecki',
#  562: 'Qasem Exirifard',
#  563: 'Davide Masoero',
#  564: 'Benedetta Mennucci',
#  565: 'Masataka Iwakuma',
#  566: 'Francis C. Fekel',
#  567: 'Tracie A. Seimon',
#  568: 'Torsten Karzig',
#  569: 'Ohad Fixler',
#  571: 'Fatiha El hatmi',
#  572: 'Aravind Chiruvelli',
#  573: 'Peter Prešnajder',
#  574: 'Irene Fernandez-Cuesta',
#  575: 'Romain Grossier',
#  576: 'J. Suchanicz',
#  577: 'Viktor Krozer',
#  579: 'Michael Tsapatsis',
#  580: 'Zlatko Jovanoski',
#  581: 'Bernhard Spanlang',
#  582: 'Enderalp Yakaboylu',
#  583: 'Ludovic Marquant',
#  584: 'Rupert F. Oulton',
#  585: 'Leila Ait Gougam',
#  586: 'Kazutaka Aonuma',
#  587: 'Yeon Kyu-Hwang',
#  588: 'Pavel Hobza',
#  589: 'Pascale Aussillous',
#  590: 'Yohko Furutono',
#  591: 'Osman Yagan',
#  592: 'Cristina Cîrtoaje',
#  593: 'Bogdan I. Epureanu',
#  594: 'Pierluigi Poggiolini',
#  595: 'Alexander P. Trishchenko',
#  596: 'Peter L. Tyack',
#  597: 'Chen Zhizhan',
#  598: 'Horacio S. Wio',
#  599: 'Mikio Uruichi',
#  600: 'Dirk Schuricht',
#  601: 'Payam Rowghanian',
#  602: 'Damien Jamon',
#  603: 'Matthias Punk',
#  604: 'Fritjof Helmchen',
#  605: 'Rémi Soummer',
#  606: 'Anders Hagfeldt',
#  607: 'Mitchell Anthamatten',
#  608: 'Yann Chachereau',
#  610: 'Noureddine Zebda',
#  611: 'Jacques Curély',
#  612: 'Rolf D. Hubmayr',
#  613: 'Alain Bossavit',
#  614: 'Oscar Reula',
#  615: 'Ashok Maliakal',
#  616: 'Christopher Molek',
#  617: 'Thorsten Lisker',
#  618: 'Corey D. Markfort',
#  619: 'Paul J. Dagdigian',
#  620: 'Constantin Chuyeshov',
#  621: 'Piotr Kurzynowski',
#  622: 'Harry M. Cullings',
#  623: 'Samuel VanGordon',
#  624: 'Gao Xuexi',
#  625: 'Patrick Chazette',
#  626: 'Chad M. Amb',
#  627: 'Lev Vaidman',
#  628: 'Gregory V. Hartland',
#  629: 'Geert Vanmeerbeeck',
#  630: 'Yu. A. Chirkunov',
#  631: 'Adam Z. Stieg',
#  632: 'Jaka Katrašnik',
#  633: 'Luis Cabarique',
#  634: 'Torsten Asselmeyer-Maluga',
#  635: 'Norbert Reitinger',
#  636: 'Stephan Denifl',
#  637: 'Antoine Van Proeyen',
#  638: 'Florian von Wrochem',
#  639: 'Peter Chabrecek',
#  640: 'Erik S. Roese',
#  641: 'Karen Yagdjian',
#  642: 'Kedron Silsbee',
#  643: 'Stamatios Lefkimmiatis',
#  644: 'Richard C. Zangar',
#  645: 'Giovanni Gallavotti',
#  646: 'Vishwajeet Mehandia',
#  647: 'Brian J. Quiter',
#  648: 'Luis Úbeda-Medina',
#  649: 'Olav Geil',
#  650: 'V. G. Tumanyan',
#  651: 'Carlos Nieto-Draghi',
#  652: 'Yu. N. Belotelova',
#  653: 'Omid Abouali',
#  654: 'Eric Madaule',
#  655: 'Yu. V. Kozhanova',
#  656: 'Mario Nicodemi',
#  657: 'Hiroaki Oshihara',
#  658: 'Sanjith Unithrattil',
#  659: 'Luca Furfaro',
#  660: 'Marco A. Cartas-Ayala',
#  661: 'Nobunori Kami-ike',
#  662: 'Olivier Roussette',
#  663: 'Boris Chayer',
#  664: 'Luca Peliti',
#  665: 'M. Dechev',
#  666: 'Rex P. Hjelm',
#  667: 'Stefano Cagliero',
#  668: 'Siriwat Soontaranon',
#  669: 'Imam Makhfudz',
#  670: 'Martin Levenius',
#  671: 'Hiroshige Kikura',
#  672: 'Cyrielle Roquelet',
#  673: 'Jovan G. Brankov',
#  674: 'Donatella Ciampini',
#  675: 'Ali Khalatpour',
#  676: 'Matthias Maiberg',
#  677: 'Eda Yildirim-Ayan',
#  678: 'Vipul Periwal',
#  679: 'Ahmad Bedram',
#  680: 'Shoichi Shige',
#  681: 'Giovanni Zanzotto',
#  682: 'Krister Bergenek',
#  683: 'Zhu Sheng-Jiang',
#  684: 'Jihane Mimih',
#  685: 'Yukiya Hakuta',
#  686: 'Adi Ditkowski',
#  687: 'Gabriele Lobaccaro',
#  688: 'Masayoshi Esashi',
#  689: 'I. Tsiaoussis',
#  690: 'Matthias Muntwiler',
#  691: 'Suzanne Van Cooten',
#  692: 'Zhang Kaizhi',
#  693: 'Elisa Guillermain',
#  694: 'Leo J. Donner',
#  695: 'Giacomo Giorli',
#  696: 'Adam Bzdak',
#  697: 'Zahra Danesh Kaftroudi',
#  698: 'Santhad Chuwongin',
#  699: 'Alexander Yarovoy',
#  700: 'Bilal Elhajjar',
#  701: 'Hikari Shimadera',
#  702: 'Donald P. Rizzetta',
#  703: 'G. Moskal',
#  704: 'Dmytro Volin',
#  705: 'Dario Zerini',
#  706: 'Christos D. Malliakas',
#  707: 'Nathalie Reckers',
#  708: 'C. Adolphsen',
#  709: 'Charles Ollion',
#  710: 'Liu Yinshui',
#  711: 'Marco Stangalini',
#  712: 'Howard M. Branz',
#  713: 'Matthew J. Krizo',
#  714: 'Uffe Bernchou',
#  715: 'Kirill Gokhberg',
#  716: 'Qu Feng-Yu',
#  717: 'David A. Rutan',
#  718: 'Viktor Szaszkó-Bogár',
#  719: 'Alexandra Zidovska',
#  720: 'Eli Dwek',
#  721: 'Miroslava Hajdúchová',
#  722: 'Ben Semerjian',
#  723: 'Aldo Frezzotti',
#  724: 'Michael R. von Spakovsky',
#  725: 'Frank Kittmann',
#  726: 'Nicolas Mazellier',
#  727: 'Yan Aru',
#  728: 'Tim Flohrer',
#  729: 'Atsushi Hariki',
#  730: 'Heike E. Daldrup-Link',
#  731: 'Mustapha Mouhcine',
#  732: 'Roman Tomaschitz',
#  733: 'Željana Bonačić Lošić',
#  734: 'Richard E. Zeebe',
#  735: 'Norbert Domaschke',
#  737: 'Sandra Mosquera-Vazquez',
#  738: 'Stefano Roddaro',
#  739: 'Bénédicte Warot-Fonrose',
#  740: 'Eric L. Brosha',
#  741: 'Matthias Eul',
#  742: 'Keith R. Lykke',
#  743: 'Seyed Ali Mousavi Shaegh',
#  744: 'L. Trouille',
#  745: 'Udo Johanningmeier',
#  746: 'Raymond E. Gordnier',
#  747: 'Igor Rodnianski',
#  748: 'Renat Sibatov',
#  749: 'Brian Mischuck',
#  750: 'Roland V. Sarmago',
#  751: 'Walter F. Wreszinski',
#  752: 'Supitcha Chanyotha',
#  753: 'Simone De Camillis',
#  754: 'Paiguy Armand Ngouateu Wouagfack',
#  755: 'Ruslan Burtovyy',
#  756: 'Yuval Birnboim',
#  757: 'Iain D. Couzin',
#  758: 'Frederick J. Gallun',
#  759: 'Hassan Rasooli Saghai',
#  760: 'Stefan Heusler',
#  761: 'Hannes Nickisch',
#  762: 'Alberto Cordero-Dávila',
#  763: 'Scott T. Retterer',
#  764: 'Sven Van Elshocht',
#  765: 'Tanja Kortemme',
#  766: 'Nicole Mazouchova',
#  767: 'Maria Magou',
#  768: 'Luis Guanter',
#  769: 'Ganapati Rao Myneni',
#  770: 'Nouraddin Mostafapoor',
#  771: 'Yann Guermeur',
#  772: 'Igor Khavkine',
#  773: 'Roman Stefak',
#  774: 'Bien Chann',
#  775: 'Hiroshi Toshiyoshi',
#  776: 'Alme Lr',
#  777: 'David Minkwitz',
#  778: 'Charis Mesaritakis',
#  779: 'Latif M. Jiji',
#  780: 'Aleksandra Drozd-Rzoska',
#  781: 'Tetsuya Iye',
#  782: 'Ivo Kabadshow',
#  783: 'R. Reudink',
#  784: 'Oscar Sánchez‐Santos',
#  785: 'Deepak K. S. Ambast',
#  786: 'Zheng Chang-Da',
#  787: 'Michael Ben-Yishai',
#  788: 'Eckehard Olbrich',
#  789: 'Jonathan Khao',
#  790: 'Roghaye Nurazar',
#  791: 'Aleksander Klauson',
#  792: 'Sukit Limpijumnong',
#  793: 'Laurent Deguillaume',
#  794: 'Eric W. Van Stryland',
#  795: 'Barbara Fresch',
#  796: 'Maria M. Koleśnik-Gray',
#  797: 'Erol Taşal',
#  798: 'Foudhil Bouakline',
#  799: 'Michele V. Bartuccelli',
#  800: 'Laurence Giraud-Moreau',
#  801: 'Chatdanai Lumdee',
#  802: 'Anastase Nakassis',
#  803: 'Dong Shun-Le',
#  804: 'Rainer Pöttgen',
#  805: 'Makoto Mashida',
#  806: 'Matthew D. Seaberg',
#  807: 'Chen Ping-Xing',
#  808: "Céline d'Orgeville",
#  809: 'Stephen E. Korbly',
#  810: 'Silas Alben',
#  811: 'Salima Saidi-Besbes',
#  812: 'Frans Gooijer',
#  813: 'Stephen C. Anco',
#  814: 'Mohamed Elawayeb',
#  815: 'Andreas Austeng',
#  816: 'David J. Brockwell',
#  817: 'Satoshi Yotsuhashi',
#  818: 'Juan C. Noveron',
#  819: 'Nobuhiro Kawatsuki',
#  820: 'Lauri Lillepea',
#  821: 'Frank Göhmann',
#  822: 'Homero Schiabel',
#  823: 'Peter Nojarov',
#  824: 'Olga Samarskaya',
#  826: 'Lorella Pascolo',
#  827: 'Tarcisio Abreu Saurin',
#  828: 'Johannes Brödel',
#  829: 'Kim Hyeon-Deuk',
#  830: 'T. Röckmann',
#  831: 'Guillaume Morard',
#  832: 'Olivier Devauchelle',
#  833: 'Vassilios Yannopapas',
#  834: 'Jérémie Joudioux',
#  835: 'Ann Karagozian',
#  836: 'Gantumur Tsogtgerel',
#  837: 'Vivian de la Incera',
#  838: 'Cherif Larbes',
#  839: 'Nooshin Kiarashi',
#  840: 'Igor Pehnec',
#  841: 'Serena Fagnocchi',
#  842: 'Dariush Abbasi-Moghadam',
#  843: 'Stefan Van Gulck',
#  844: 'Etienne Renotte',
#  845: 'Susan B. Sinnott',
#  846: 'Serge Karabchevsky',
#  847: 'Gabriela Ambrožič',
#  848: 'Kai Germaschewski',
#  849: 'Søren Herstrøm',
#  850: 'R. Tantalo',
#  851: 'Andreas Koeberle',
#  852: 'Pierluigi Di Lizia',
#  853: 'David H. Waldeck',
#  854: 'Anatoliy A. Kosterev',
#  855: 'Hajime Susa',
#  856: 'Gabriel D. Gwanmesia',
#  857: 'Wang Dian-hong',
#  858: 'Mohsen Alishahiha',
#  859: 'Chen Shuming',
#  860: 'Yoshihisa Sensu',
#  861: 'Matthew J. Krasin',
#  862: 'Shi Yu-Ren',
#  863: 'Lars Murrer',
#  864: 'Omri Bahat-Treidel',
#  865: 'Tapan Chandra Adhyapak',
#  866: 'David Dasenbrook',
#  867: 'Marcin Stolarek',
#  868: 'Izuru Senaha',
#  869: 'Gabriella Caminati',
#  870: 'Gerasimos Konstantatos',
#  871: 'Lionel Tabourier',
#  872: 'Hsieh Fushing',
#  874: 'Andrew O. Sageman-Furnas',
#  875: 'Frédéric Parol',
#  876: 'Edward Perepelitsky',
#  877: 'Jorge Castro-Ramos',
#  878: 'Roberto Guardani',
#  879: 'Paul Maragakis',
#  880: 'Michael R. Wasielewski',
#  881: 'Mehrdad Amirghasemi',
#  882: 'Francisco Bezanilla',
#  883: 'Ann N. Chiaramonti',
#  884: 'Marco Pagliazzi',
#  885: 'Maria Farsari',
#  886: 'Chen Ling-yan',
#  887: 'Brita Elvevåg',
#  888: 'Thomas Tromholt',
#  889: 'Demosthenes Ellinas',
#  890: 'Dane W. deQuilettes',
#  891: 'Ari Mujunen',
#  892: 'Michael F. McNitt-Gray',
#  893: 'Masaru Inatsu',
#  894: 'Zoran Utkovski',
#  895: 'Ezio Mancaruso',
#  896: 'Eric J. Steig',
#  897: 'Kang Jun-yong',
#  898: 'Hadi Saboohi',
#  899: 'Edoardo Charbon',
#  900: 'Febiana Tjiptoharsono',
#  901: 'Fang Jian-Shu',
#  902: 'Abdolhakim Pangh',
#  903: 'Hironobu Unesaki',
#  904: 'Sapana Ranwa',
#  905: 'Giacomo Cacciapaglia',
#  906: 'Isabelle Choquet',
#  907: 'L. N. Vyacheslavov',
#  908: 'Guy Ennekens',
#  909: 'Olivier Nguon',
#  910: 'Jean Schmittbuhl',
#  911: 'Ignacio Birriel',
#  912: 'Grunde Olimstad',
#  913: 'Alexei A. Pevtsov',
#  914: 'Jan De Cuveland',
#  915: 'Davis D. Sentman',
#  916: 'Markus Meuwly',
#  917: 'Valerio Cozzani',
#  918: 'David Coulot',
#  919: 'Laura K. McKemmish',
#  920: 'Edgardo García-Berríos',
#  921: 'Andrew M. Dattelbaum',
#  922: 'Simon Mitternacht',
#  923: 'Dean M. DeLongchamp',
#  924: 'Miguel Pineirua',
#  925: 'Muhammad Aslam Malana',
#  926: 'David Zimdars',
#  927: 'Claude Duhr',
#  928: 'Yu.A. Merkuliev',
#  929: 'Thomas Ruedas',
#  930: 'George A. Gravvanis',
#  931: 'Maya Paczuski',
#  932: 'Prasanta Dhak',
#  933: 'Dana I. Casetti-Dinescu',
#  934: 'Pablo G. Debenedetti',
#  935: 'Boudewijn F. Roukema',
#  936: 'Yu. V. Chichagov',
#  937: 'Arttu Luukanen',
#  938: 'Anna Celler',
#  939: 'Farid Chejne',
#  940: 'Daisuke Onoshima',
#  941: 'Erick A. Juarez-Arellano',
#  942: 'Florian Kapsenberg',
#  943: 'Lü Jun-Guang',
#  944: 'Vinay Ambegaokar',
#  945: 'Tomáš Mančal',
#  946: 'Philippe Martinive',
#  947: 'S.J. Zinkle',
#  948: 'Renata Prunskaite-Hyyryläinen',
#  949: 'Keitaro Tanoi',
#  950: 'S. Poncsak',
#  951: 'Ilaria Jemos',
#  952: 'Ren Wanbin',
#  953: 'Andrew J. Orr-Ewing',
#  954: 'Yoshiyuki Nonoguchi',
#  955: 'Romain Vexiau',
#  956: 'Boosayarat Tomapatanaget',
#  957: 'Jamal T. Manassah',
#  958: 'Sergei V. Belchikov',
#  959: 'W. Vodel',
#  960: 'Ulman Lindenberger',
#  961: 'Sophie Laffray',
#  962: 'Robert E. Dinnebier',
#  963: 'Jérôme Pratlong',
#  964: 'Frasher Loshaj',
#  965: 'Andreas Schadschneider',
#  966: 'Vladimir Temchura',
#  967: 'Umarporn Charusombat',
#  968: 'Pietro Guarato',
#  969: 'Qin Su-Juan',
#  971: 'Dorota A. Grejner-Brzezinska',
#  972: 'Stavros C. Farantos',
#  973: 'Dan Winske',
#  974: 'Benoit Glorieux',
#  975: 'Feng Xueshang',
#  976: 'Mir Behrad Khamesee',
#  977: 'Gary Shambat',
#  978: 'Payvand Taherparvar',
#  979: 'Daniella Yeheskely-Hayon',
#  980: 'Eivind Almaas',
#  981: 'Anne Dominique Cambou',
#  982: 'Martin Spinrath',
#  983: 'Tomasz Kalwarczyk',
#  984: 'Corinna Kollath',
#  985: 'Zacharie Tamainot-Telto',
#  986: 'Robert L. Washeleski',
#  987: 'Nigel S. Scrutton',
#  988: 'Jahan M. Dawlaty',
#  989: 'Yu. V. Shaldin',
#  990: 'Björgvin Hjörvarsson',
#  991: 'Andrey A. Shoom',
#  992: 'Abderrazek Khalfallaoui',
#  993: 'Bernd R.T. Simoneit',
#  994: 'Romualdo Pastor-Satorras',
#  995: 'Antonio Carlos Bannwart',
#  996: 'Astrid M. L. Kappers',
#  997: 'Claire Mangeney',
#  998: 'Sahar Ahmadipanah',
#  999: 'Winai Jaikla',
#  1000: 'Dganit Danino',
#  1001: 'Hidekatsu Nemura',
#  1002: 'Ernst Niederleithinger',
#  1003: 'Santiago Esplugas',
#  1004: 'Pieter Slagmolen',
#  1005: 'Vassilios Fessatidis',
#  1006: 'Thomas Bligaard',
#  1007: 'Nongnuch Artrith',
#  1008: 'Jonathan Vappou',
#  1009: 'Chiel C. van Heerwaarden',
#  1010: 'Rajesh R. Parwani',
#  1011: 'Nicole Janotte',
#  1012: 'Yoshio Kitadono',
#  1013: 'Valérie Monbet',
#  ...}

# %%
author_embedding_dict = {}

for chunk in tqdm(chunked(author_names_dict.items(), 10000)):
    ids, names = zip(*chunk)
    name_embeddings = embedding_model.embed_documents(names)

    recs = [{'nodeId': id, 'textEmbedding': torch.tensor(name_embedding).unsqueeze(0)} for id, name_embedding in zip(ids, name_embeddings)]

    embeddings_dict = {id : name_embedding for id, name_embedding in zip(ids, name_embeddings)}
    author_embedding_dict.update(embeddings_dict)
# Out:
# 111it [52:12, 28.22s/it]

# %%
len(author_embedding_dict)
# Out:
# 1104554

# %%
import torch
torch.save(author_embedding_dict, 'emb/mag/text-embedding-ada-002/doc/author_embedding_dict.pt')

# %%
len(author_embedding[0])
# Out:
# 1536

# %%
with GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD)) as driver:
    author_embedding = torch.load('emb/mag/text-embedding-ada-002/doc/author_embedding_dict.pt', weights_only=False)
    insert_node_embeddings(embeddings=author_embedding, embedding_name='textEmbedding', driver=driver)
# Out:
# ======  Loading embeddings (textEmbedding) ======
# 100%|██████████| 1104554/1104554 [57:55<00:00, 317.84it/s]

# %%
with GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD)) as driver:
    insert_node_embeddings(embeddings=author_embedding, embedding_name='textEmbedding', driver=driver)
# Out:
# ======  Loading embeddings (textEmbedding) ======
#   2%|▏         | 22000/1104554 [01:02<51:06, 353.05it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[68], line 2
#       1 with GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD)) as driver:
# ----> 2     insert_node_embeddings(embeddings=author_embedding, embedding_name='textEmbedding', driver=driver)
#
# File ~/GraphRAFT/data_loading/stark_neo4j_loading.py:71, in insert_node_embeddings(embeddings, embedding_name, driver)
#      69 with tqdm(total=len(paper_emb_records)) as pbar:
#      70     for recs in _chunks(paper_emb_records, 1_000):
# ---> 71         driver.execute_query(query, parameters_={'recs': recs, 'embeddingName': embedding_name})
#      72         pbar.update(len(recs))
#      74     dim = 1536
#
# File ~/miniforge3/envs/graphraft/lib/python3.11/site-packages/neo4j/_sync/driver.py:959, in Driver.execute_query(self, query_, parameters_, routing_, database_, impersonated_user_, bookmark_manager_, auth_, result_transformer_, **kwargs)
#     956     raise ValueError("Invalid routing control value: %r"
#     957                      % routing_)
#     958 with session._pipelined_begin:
# --> 959     return session._run_transaction(
#     960         access_mode, TelemetryAPI.DRIVER,
#     961         work, (query_str, parameters, result_transformer_), {}
#     962     )
#
# File ~/miniforge3/envs/graphraft/lib/python3.11/site-packages/neo4j/_sync/work/session.py:554, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     552 tx = self._transaction
#     553 try:
# --> 554     result = transaction_function(tx, *args, **kwargs)
#     555 except asyncio.CancelledError:
#     556     # if cancellation callback has not been called yet:
#     557     if self._transaction is not None:
#
# File ~/miniforge3/envs/graphraft/lib/python3.11/site-packages/neo4j/_sync/driver.py:1290, in _work(tx, query, parameters, transformer)
#    1284 def _work(
#    1285     tx: ManagedTransaction,
#    1286     query: te.LiteralString,
#    1287     parameters: t.Dict[str, t.Any],
#    1288     transformer: t.Callable[[Result], t.Union[_T]]
#    1289 ) -> _T:
# -> 1290     res = tx.run(query, parameters)
#    1291     return transformer(res)
#
# File ~/miniforge3/envs/graphraft/lib/python3.11/site-packages/neo4j/_sync/work/transaction.py:172, in TransactionBase.run(self, query, parameters, **kwparameters)
#     169 self._results.append(result)
#     171 parameters = dict(parameters or {}, **kwparameters)
# --> 172 result._tx_ready_run(query, parameters)
#     174 return result
#
# File ~/miniforge3/envs/graphraft/lib/python3.11/site-packages/neo4j/_sync/work/result.py:171, in Result._tx_ready_run(self, query, parameters)
#     167 def _tx_ready_run(self, query, parameters):
#     168     # BEGIN+RUN does not carry any extra on the RUN message.
#     169     # BEGIN {extra}
#     170     # RUN "query" {parameters} {extra}
# --> 171     self._run(query, parameters, None, None, None, None, None, None)
#
# File ~/miniforge3/envs/graphraft/lib/python3.11/site-packages/neo4j/_sync/work/result.py:203, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     200     self._attached = False
#     201     Util.callback(self._on_closed)
# --> 203 self._connection.run(
#     204     query_text,
#     205     parameters=parameters,
#     206     mode=access_mode,
#     207     bookmarks=bookmarks,
#     208     metadata=query_metadata,
#     209     timeout=query_timeout,
#     210     db=db,
#     211     imp_user=imp_user,
#     212     notifications_min_severity=notifications_min_severity,
#     213     notifications_disabled_classifications=
#     214         notifications_disabled_classifications,
#     215     dehydration_hooks=self._hydration_scope.dehydration_hooks,
#     216     on_success=on_attached,
#     217     on_failure=on_failed_attach,
#     218 )
#     219 self._pull()
#     220 self._connection.send_all()
#
# File ~/miniforge3/envs/graphraft/lib/python3.11/site-packages/neo4j/_sync/io/_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     176 def inner(*args, **kwargs):
#     177     try:
# --> 178         func(*args, **kwargs)
#     179     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     180         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File ~/miniforge3/envs/graphraft/lib/python3.11/site-packages/neo4j/_sync/io/_bolt5.py:740, in Bolt5x5.run(self, query, parameters, mode, bookmarks, metadata, timeout, db, imp_user, notifications_min_severity, notifications_disabled_classifications, dehydration_hooks, hydration_hooks, **handlers)
#     737     extra["tx_timeout"] = tx_timeout_as_ms(timeout)
#     738 fields = (query, parameters, extra)
#     739 log.debug("[#%04X]  C: RUN %s", self.local_port,
# --> 740           " ".join(map(repr, fields)))
#     741 self._append(b"\x10", fields,
#     742              Response(self, "run", hydration_hooks, **handlers),
#     743              dehydration_hooks=dehydration_hooks)
#
# KeyboardInterrupt:

# %%
institution_df
# Out:
#         id      mag_id   Rank                          DisplayName  \
# 0        0        9507  11616                    Sangji University
# 1        1       19722  11471          Ateneo de Manila University
# 2        2       41870  11530      Instituto Militar de Engenharia
# 3        3       43886  13361                 Sapientia University
# 4        4       46017  10780  Kahramanmaraş Sütçü İmam University
# ...    ...         ...    ...                                  ...
# 8696  8735  2961216182     -1                                   -1
# 8697  8736  2972652528     -1                                   -1
# 8698  8737  3004594783     -1                                   -1
# 8699  8738  3005327000     -1                                   -1
# 8700  8739  3006985408     -1                                   -1
#
#       PaperCount  CitationCount         type   new_id
# 0           1259          10636  institution  1104554
# 1           1467           8557  institution  1104555
# 2           1289           9985  institution  1104556
# 3            265           1173  institution  1104557
# 4           1928          20112  institution  1104558
# ...          ...            ...          ...      ...
# 8696          -1             -1  institution  1113250
# 8697          -1             -1  institution  1113251
# 8698          -1             -1  institution  1113252
# 8699          -1             -1  institution  1113253
# 8700          -1             -1  institution  1113254
#
# [8701 rows x 8 columns]

# %%
institution_names = institution_df['DisplayName'].tolist()
institution_names = [str(x) for x in institution_names]
institution_nodeids = institution_df['id'].tolist()
institution_names_dict = {i: name for i, name in zip(institution_nodeids, institution_names)}

# %%
institution_embedding_dict = {}

for chunk in tqdm(chunked(institution_names_dict.items(), 10000)):
    ids, names = zip(*chunk)
    name_embeddings = embedding_model.embed_documents(names)

    embeddings_dict = {id : name_embedding for id, name_embedding in zip(ids, name_embeddings)}
    institution_embedding_dict.update(embeddings_dict)
# Out:
# 1it [00:24, 24.46s/it]

# %%
torch.save(institution_embedding_dict, 'emb/mag/text-embedding-ada-002/doc/institution_emb_dict.pt')

# %%
with GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD)) as driver:
    institution_embedding = torch.load('emb/mag/text-embedding-ada-002/doc/institution_emb_dict.pt', weights_only=False)
    insert_node_embeddings(embeddings=institution_embedding, embedding_name='textEmbedding', driver=driver)
# Out:
# ======  Loading embeddings (textEmbedding) ======
# 100%|██████████| 8701/8701 [00:24<00:00, 354.29it/s]

# %%
field_of_study_df
# Out:
#           id      mag_id   Rank                DisplayName  Level  PaperCount  \
# 0          0        4250  15252              Sign function      3         820
# 1          1       12843  11980  Gravitational singularity      2       29654
# 2          2       20288  11787         Superstring theory      3        6772
# 3          3       37253  12134      Complete intersection      2        2428
# 4          4       39854  13346           Torque converter      3       15356
# ...      ...         ...    ...                        ...    ...         ...
# 59464  59960  2994609373     -1                         -1     -1          -1
# 59465  59961  2994609795     -1                         -1     -1          -1
# 59466  59962  2994609957     -1                         -1     -1          -1
# 59467  59963  2994610206     -1                         -1     -1          -1
# 59468  59964  2994610307     -1                         -1     -1          -1
#
#        CitationCount            type   new_id
# 0               7533  field_of_study  1113255
# 1             338027  field_of_study  1113256
# 2             160417  field_of_study  1113257
# 3              27280  field_of_study  1113258
# 4              91481  field_of_study  1113259
# ...              ...             ...      ...
# 59464             -1  field_of_study  1172719
# 59465             -1  field_of_study  1172720
# 59466             -1  field_of_study  1172721
# 59467             -1  field_of_study  1172722
# 59468             -1  field_of_study  1172723
#
# [59469 rows x 9 columns]

# %%
field_of_study_names = field_of_study_df['DisplayName'].tolist()
field_of_study_names = [str(x) for x in field_of_study_names]
field_of_study_nodeids = field_of_study_df['id'].tolist()
field_of_study_names_dict = {i: name for i, name in zip(field_of_study_nodeids, field_of_study_names)}

# %%
field_of_study_embedding_dict = {}

for chunk in tqdm(chunked(field_of_study_names_dict.items(), 10000)):
    ids, names = zip(*chunk)
    name_embeddings = embedding_model.embed_documents(names)

    embeddings_dict = {id : name_embedding for id, name_embedding in zip(ids, name_embeddings)}
    field_of_study_embedding_dict.update(embeddings_dict)
# Out:
# 6it [02:50, 28.40s/it]

# %%
torch.save(field_of_study_embedding_dict, 'emb/mag/text-embedding-ada-002/doc/field_of_study_embedding_dict.pt')

# %%
type(field_of_study_embedding)
# Out:
# dict

# %%
with GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD)) as driver:
    field_of_study_embedding = torch.load('emb/mag/text-embedding-ada-002/doc/field_of_study_embedding_dict.pt', weights_only=False)
    insert_node_embeddings(embeddings=field_of_study_embedding, embedding_name='textEmbedding', driver=driver)
# Out:
# ======  Loading embeddings (textEmbedding) ======
# 100%|██████████| 59469/59469 [03:16<00:00, 302.98it/s]

# %%
abstract_embeddings = torch.load('./mag/text-embedding-ada-002/doc/candidate_emb_dict.pt', weights_only=False)
with GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD)) as driver:
    insert_node_embeddings(embeddings=abstract_embeddings, embedding_name='textEmbedding', driver=driver)
# Out:
# ======  Loading embeddings (textEmbedding) ======
# 100%|██████████| 700244/700244 [35:54<00:00, 325.08it/s]

# %%
# create vector index

with GraphDatabase.driver(NEO4J_URI,
                          auth=(NEO4J_USERNAME, NEO4J_PASSWORD)) as driver:
  driver.execute_query('''
  CREATE VECTOR INDEX text_embeddings IF NOT EXISTS FOR (n:_Entity_) ON (n.textEmbedding)
  OPTIONS {indexConfig: {
  `vector.dimensions`: toInteger($dimension),
  `vector.similarity_function`: 'cosine'
  }}''', parameters_={'dimension': 1536})
  driver.execute_query('CALL db.awaitIndex("text_embeddings", 500)')
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[16], line 11
#       3 with GraphDatabase.driver(NEO4J_URI,
#       4                           auth=(NEO4J_USERNAME, NEO4J_PASSWORD)) as driver:
#       5   driver.execute_query('''
#       6   CREATE VECTOR INDEX text_embeddings IF NOT EXISTS FOR (n:_Entity_) ON (n.textEmbedding)
#       7   OPTIONS {indexConfig: {
#       8   `vector.dimensions`: toInteger($dimension),
#       9   `vector.similarity_function`: 'cosine'
#      10   }}''', parameters_={'dimension': 1536})
# ---> 11   driver.execute_query('CALL db.awaitIndex("text_embeddings", 300)')
#
# File ~/miniforge3/envs/graphraft/lib/python3.11/site-packages/neo4j/_sync/driver.py:959, in Driver.execute_query(self, query_, parameters_, routing_, database_, impersonated_user_, bookmark_manager_, auth_, result_transformer_, **kwargs)
#     956     raise ValueError("Invalid routing control value: %r"
#     957                      % routing_)
#     958 with session._pipelined_begin:
# --> 959     return session._run_transaction(
#     960         access_mode, TelemetryAPI.DRIVER,
#     961         work, (query_str, parameters, result_transformer_), {}
#     962     )
#
# File ~/miniforge3/envs/graphraft/lib/python3.11/site-packages/neo4j/_sync/work/session.py:554, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     552 tx = self._transaction
#     553 try:
# --> 554     result = transaction_function(tx, *args, **kwargs)
#     555 except asyncio.CancelledError:
#     556     # if cancellation callback has not been called yet:
#     557     if self._transaction is not None:
#
# File ~/miniforge3/envs/graphraft/lib/python3.11/site-packages/neo4j/_sync/driver.py:1290, in _work(tx, query, parameters, transformer)
#    1284 def _work(
#    1285     tx: ManagedTransaction,
#    1286     query: te.LiteralString,
#    1287     parameters: t.Dict[str, t.Any],
#    1288     transformer: t.Callable[[Result], t.Union[_T]]
#    1289 ) -> _T:
# -> 1290     res = tx.run(query, parameters)
#    1291     return transformer(res)
#
# File ~/miniforge3/envs/graphraft/lib/python3.11/site-packages/neo4j/_sync/work/transaction.py:172, in TransactionBase.run(self, query, parameters, **kwparameters)
#     169 self._results.append(result)
#     171 parameters = dict(parameters or {}, **kwparameters)
# --> 172 result._tx_ready_run(query, parameters)
#     174 return result
#
# File ~/miniforge3/envs/graphraft/lib/python3.11/site-packages/neo4j/_sync/work/result.py:171, in Result._tx_ready_run(self, query, parameters)
#     167 def _tx_ready_run(self, query, parameters):
#     168     # BEGIN+RUN does not carry any extra on the RUN message.
#     169     # BEGIN {extra}
#     170     # RUN "query" {parameters} {extra}
# --> 171     self._run(query, parameters, None, None, None, None, None, None)
#
# File ~/miniforge3/envs/graphraft/lib/python3.11/site-packages/neo4j/_sync/work/result.py:221, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     219 self._pull()
#     220 self._connection.send_all()
# --> 221 self._attach()
#
# File ~/miniforge3/envs/graphraft/lib/python3.11/site-packages/neo4j/_sync/work/result.py:409, in Result._attach(self)
#     407 if self._exhausted is False:
#     408     while self._attached is False:
# --> 409         self._connection.fetch_message()
#
# File ~/miniforge3/envs/graphraft/lib/python3.11/site-packages/neo4j/_sync/io/_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     176 def inner(*args, **kwargs):
#     177     try:
# --> 178         func(*args, **kwargs)
#     179     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     180         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File ~/miniforge3/envs/graphraft/lib/python3.11/site-packages/neo4j/_sync/io/_bolt.py:860, in Bolt.fetch_message(self)
#     856 # Receive exactly one message
#     857 tag, fields = self.inbox.pop(
#     858     hydration_hooks=self.responses[0].hydration_hooks
#     859 )
# --> 860 res = self._process_message(tag, fields)
#     861 self.idle_since = monotonic()
#     862 return res
#
# File ~/miniforge3/envs/graphraft/lib/python3.11/site-packages/neo4j/_sync/io/_bolt5.py:370, in Bolt5x0._process_message(self, tag, fields)
#     368 self._server_state_manager.state = self.bolt_states.FAILED
#     369 try:
# --> 370     response.on_failure(summary_metadata or {})
#     371 except (ServiceUnavailable, DatabaseUnavailable):
#     372     if self.pool:
#
# File ~/miniforge3/envs/graphraft/lib/python3.11/site-packages/neo4j/_sync/io/_common.py:245, in Response.on_failure(self, metadata)
#     243 handler = self.handlers.get("on_summary")
#     244 Util.callback(handler)
# --> 245 raise Neo4jError.hydrate(**metadata)
#
# ClientError: {code: Neo.ClientError.Procedure.ProcedureTimedOut} {message: Index on 'Index( id=4, name='text_embeddings', type='VECTOR', schema=(:_Entity_ {textEmbedding}), indexProvider='vector-2.0' )' did not come online within 300 SECONDS}

# %%
# Create reltype_emb_dict.py

# %%
import re

def format_rel_type(s):

  return re.sub('[^0-9A-Z]+', '_', s.upper())

# %%
from langchain_openai import OpenAIEmbeddings
embedding_model = OpenAIEmbeddings(model="text-embedding-ada-002")
reltype_emb = {format_rel_type(v): embedding_model.embed_query(v) for k,v in  skb.edge_type_dict.items()}
# dict_keys currently is: dict_keys(['AUTHOR_AFFILIATED_WITH_INSTITUTION', 'PAPER_CITES_PAPER', 'PAPER_HAS_TOPIC_FIELD_OF_STUDY', 'AUTHOR_WRITES_PAPER'])
# Remove the source node and target node type from the key names

# %%
reltype_emb.keys()
# Out:
# dict_keys(['AUTHOR_AFFILIATED_WITH_INSTITUTION', 'PAPER_CITES_PAPER', 'PAPER_HAS_TOPIC_FIELD_OF_STUDY', 'AUTHOR_WRITES_PAPER'])

# %%
# Mapping for renaming keys
key_mapping = {
    'AUTHOR_AFFILIATED_WITH_INSTITUTION': 'AFFILIATED_WITH',
    'PAPER_CITES_PAPER': 'CITES',
    'PAPER_HAS_TOPIC_FIELD_OF_STUDY': 'HAS_TOPIC',
    'AUTHOR_WRITES_PAPER': 'WRITES',
}

# %%
renamed_data = {key_mapping[k]: v for k, v in reltype_emb.items()}

# %%
renamed_data.keys()
# Out:
# dict_keys(['AFFILIATED_WITH', 'CITES', 'HAS_TOPIC', 'WRITES'])

# %%
import torch

torch.save(renamed_data, 'emb/mag/text-embedding-ada-002/doc/reltype_emb_dict.pt')
